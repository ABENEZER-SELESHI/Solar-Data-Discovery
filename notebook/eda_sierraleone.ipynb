# %% [markdown]
# <a href="https://colab.research.google.com/github/ABENEZER-SELESHI/Solar-Data-Discovery/blob/main/eda_sierraleone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Load Dataset
df = pd.read_csv('/content/sierraleone-bumbuna.csv')

print(df.head())
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# 2. Summary Statistics & Missing-Value Report
print("\n=== Summary Statistics ===")
print(df.describe())

print("\n=== Missing Values (count & %) ===")
missing_count = df.isna().sum()
missing_pct   = df.isna().mean() * 100
missing_report = pd.DataFrame({'count': missing_count, 'percent': missing_pct})
# 2. Summary Statistics & Missing-Value Report
print("\n=== Summary Statistics ===")
print(df.describe())

print("\n=== Missing Values (count & %) ===")
missing_count = df.isna().sum()
missing_pct   = df.isna().mean() * 100
missing_report = pd.DataFrame({'count': missing_count, 'percent': missing_pct})
print(missing_report[missing_report['percent'] > 0])  # flag >0% or >5%

print("\n=== Missing Values (count & %) ===")
missing_count = df.isna().sum()
missing_pct   = df.isna().mean() * 100
missing_report = pd.DataFrame({'count': missing_count, 'percent': missing_pct})
print(missing_report[missing_report['percent'] > 0])  # flag >0% or >5%
missing_pct   = df.isna().mean() * 100
missing_report = pd.DataFrame({'count': missing_count, 'percent': missing_pct})
print(missing_report[missing_report['percent'] > 0])  # flag >0% or >5%
# Out:
# === Summary Statistics ===
#                 GHI           DNI           DHI          ModA          ModB  \
# count  72242.000000  72242.000000  72242.000000  72242.000000  72242.000000
# mean     209.274976    156.908804     98.881757    228.302584    219.112628
# std      303.375719    262.096959    134.628864    330.359951    318.303992
# min       -7.400000     -3.900000     -7.300000      0.000000      0.000000
# 25%       -1.500000     -0.300000     -1.600000      0.000000      0.000000
# 50%       -0.400000     -0.100000     -0.400000      0.500000      0.400000
# mean     133.311185      6.569251    999.27927      0.000872       0.001408
# std      118.555742      7.564878      1.76281      0.029518       0.022406
# min        0.000000      0.000000    995.00000      0.000000       0.000000
# 25%        0.000000      0.000000    998.00000      0.000000       0.000000
# 50%      131.600000      4.300000    999.00000      0.000000       0.000000
# 75%      246.100000     11.300000   1000.00000      0.000000       0.000000
# max      360.000000     93.300000   1006.00000      1.000000       1.500000
#
#               TModA         TModB  Comments
# count  72242.000000  72241.000000       0.0
# mean      34.003365     33.923078       NaN
# std       13.950677     13.176981       NaN
# min        2.000000     17.900000       NaN
# 25%       23.400000     23.700000       NaN
# 50%       25.900000     26.300000       NaN
# 75%       45.300000     45.400000       NaN
# max       72.800000     66.900000       NaN
#
# === Missing Values (count & %) ===
#           count     percent
# TModB         1    0.001384
# Comments  72242  100.000000
#
# === Missing Values (count & %) ===
#           count     percent
# TModB         1    0.001384
# Comments  72242  100.000000
#           count     percent
# TModB         1    0.001384
# Comments  72242  100.000000

# %%
# Summary statistics for numerical columns
print(df.describe())
# Out:
#                 GHI           DNI           DHI          ModA          ModB  \
# count  72242.000000  72242.000000  72242.000000  72242.000000  72242.000000
# mean     209.274976    156.908804     98.881757    228.302584    219.112628
# std      303.375719    262.096959    134.628864    330.359951    318.303992
# min       -7.400000     -3.900000     -7.300000      0.000000      0.000000
# 25%       -1.500000     -0.300000     -1.600000      0.000000      0.000000
# 50%       -0.400000     -0.100000     -0.400000      0.500000      0.400000
# 75%      381.475000    255.075000    195.800000    412.975000    393.000000
# max     1232.000000    896.000000    666.000000   1316.000000   1285.000000
#
#                Tamb            RH            WS        WSgust       WSstdev  \
# count  72242.000000  72242.000000  72242.000000  72242.000000  72242.000000
# mean      26.386462     84.905480      0.974862      1.436549      0.336930
# std        3.836359     14.922959      1.010714      1.309860      0.256149
# min       18.200000     29.600000      0.000000      0.000000      0.000000
# 25%       23.200000     72.400000      0.000000      0.000000      0.000000
# 50%       25.300000     91.600000      0.800000      1.400000      0.400000
# 75%       30.100000     97.500000      1.700000      2.400000      0.500000
# max       36.300000    100.000000     10.100000     13.800000      3.500000
#
#                  WD       WDstdev           BP      Cleaning  Precipitation  \
# count  72242.000000  72242.000000  72242.00000  72242.000000   72242.000000
# mean     133.311185      6.569251    999.27927      0.000872       0.001408
# std      118.555742      7.564878      1.76281      0.029518       0.022406
# min        0.000000      0.000000    995.00000      0.000000       0.000000
# 25%        0.000000      0.000000    998.00000      0.000000       0.000000
# 50%      131.600000      4.300000    999.00000      0.000000       0.000000
# 75%      246.100000     11.300000   1000.00000      0.000000       0.000000
# max      360.000000     93.300000   1006.00000      1.000000       1.500000
#
#               TModA         TModB  Comments
# count  72242.000000  72241.000000       0.0
# mean      34.003365     33.923078       NaN
# std       13.950677     13.176981       NaN
# min        2.000000     17.900000       NaN
# 25%       23.400000     23.700000       NaN
# 50%       25.900000     26.300000       NaN
# 75%       45.300000     45.400000       NaN
# max       72.800000     66.900000       NaN

# %%
# Summary for all columns, including object types
print(df.describe(include='all'))
# Out:
#                Timestamp           GHI           DNI           DHI  \
# count              72242  72242.000000  72242.000000  72242.000000
# unique             72242           NaN           NaN           NaN
# top     2021-12-19 04:02           NaN           NaN           NaN
# freq                   1           NaN           NaN           NaN
# mean                 NaN    209.274976    156.908804     98.881757
# std                  NaN    303.375719    262.096959    134.628864
# min                  NaN     -7.400000     -3.900000     -7.300000
# 25%                  NaN     -1.500000     -0.300000     -1.600000
# 50%                  NaN     -0.400000     -0.100000     -0.400000
# 75%                  NaN    381.475000    255.075000    195.800000
# max                  NaN   1232.000000    896.000000    666.000000
#
#                 ModA          ModB          Tamb            RH            WS  \
# count   72242.000000  72242.000000  72242.000000  72242.000000  72242.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean      228.302584    219.112628     26.386462     84.905480      0.974862
# std       330.359951    318.303992      3.836359     14.922959      1.010714
# min         0.000000      0.000000     18.200000     29.600000      0.000000
# 25%         0.000000      0.000000     23.200000     72.400000      0.000000
# 50%         0.500000      0.400000     25.300000     91.600000      0.800000
# 75%       412.975000    393.000000     30.100000     97.500000      1.700000
# max      1316.000000   1285.000000     36.300000    100.000000     10.100000
#
#               WSgust       WSstdev            WD       WDstdev           BP  \
# count   72242.000000  72242.000000  72242.000000  72242.000000  72242.00000
# unique           NaN           NaN           NaN           NaN          NaN
# top              NaN           NaN           NaN           NaN          NaN
# freq             NaN           NaN           NaN           NaN          NaN
# mean        1.436549      0.336930    133.311185      6.569251    999.27927
# std         1.309860      0.256149    118.555742      7.564878      1.76281
# min         0.000000      0.000000      0.000000      0.000000    995.00000
# 25%         0.000000      0.000000      0.000000      0.000000    998.00000
# 50%         1.400000      0.400000    131.600000      4.300000    999.00000
# 75%         2.400000      0.500000    246.100000     11.300000   1000.00000
# max        13.800000      3.500000    360.000000     93.300000   1006.00000
#
#             Cleaning  Precipitation         TModA         TModB  Comments
# count   72242.000000   72242.000000  72242.000000  72241.000000       0.0
# unique           NaN            NaN           NaN           NaN       NaN
# top              NaN            NaN           NaN           NaN       NaN
# freq             NaN            NaN           NaN           NaN       NaN
# mean        0.000872       0.001408     34.003365     33.923078       NaN
# std         0.029518       0.022406     13.950677     13.176981       NaN
# min         0.000000       0.000000      2.000000     17.900000       NaN
# 25%         0.000000       0.000000     23.400000     23.700000       NaN
# 50%         0.000000       0.000000     25.900000     26.300000       NaN
# 75%         0.000000       0.000000     45.300000     45.400000       NaN
# max         1.000000       1.500000     72.800000     66.900000       NaN

# %%
# Count of missing values in each column
print(df.isnull().sum())
# Out:
# Timestamp            0
# GHI                  0
# DNI                  0
# DHI                  0
# ModA                 0
# ModB                 0
# Tamb                 0
# RH                   0
# WS                   0
# WSgust               0
# WSstdev              0
# WD                   0
# WDstdev              0
# BP                   0
# Cleaning             0
# Precipitation        0
# TModA                0
# TModB                1
# Comments         72242
# dtype: int64

# %%
# Missing value percentage per column
missing_percent = df.isnull().mean() * 100
print(missing_percent)
# Out:
# Timestamp          0.000000
# GHI                0.000000
# DNI                0.000000
# DHI                0.000000
# ModA               0.000000
# ModB               0.000000
# Tamb               0.000000
# RH                 0.000000
# WS                 0.000000
# WSgust             0.000000
# WSstdev            0.000000
# WD                 0.000000
# WDstdev            0.000000
# BP                 0.000000
# Cleaning           0.000000
# Precipitation      0.000000
# TModA              0.000000
# TModB              0.001384
# Comments         100.000000
# dtype: float64

# %%
# Combined missing value count and percentage
missing_report = pd.DataFrame({
    'Missing Count': df.isnull().sum(),
    'Missing %': df.isnull().mean() * 100
})
print(missing_report)
# Out:
#                Missing Count   Missing %
# Timestamp                  0    0.000000
# GHI                        0    0.000000
# DNI                        0    0.000000
# DHI                        0    0.000000
# ModA                       0    0.000000
# ModB                       0    0.000000
# Tamb                       0    0.000000
# RH                         0    0.000000
# WS                         0    0.000000
# WSgust                     0    0.000000
# WSstdev                    0    0.000000
# WD                         0    0.000000
# WDstdev                    0    0.000000
# BP                         0    0.000000
# Cleaning                   0    0.000000
# Precipitation              0    0.000000
# TModA                      0    0.000000
# TModB                      1    0.001384
# Comments               72242  100.000000

# %%
# Loop through numerical columns and identify outliers using IQR
numerical_cols = df.select_dtypes(include=['number']).columns

outliers = {}

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outlier_rows = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outliers[col] = len(outlier_rows)

# Show number of outliers per column
print("Outlier count per numerical column:")
print(outliers)
# Out:
# Outlier count per numerical column:
# {'GHI': 890, 'DNI': 7315, 'DHI': 516, 'ModA': 922, 'ModB': 1295, 'Tamb': 0, 'RH': 68, 'WS': 325, 'WSgust': 253, 'WSstdev': 149, 'WD': 0, 'WDstdev': 908, 'BP': 1051, 'Cleaning': 63, 'Precipitation': 564, 'TModA': 0, 'TModB': 0, 'Comments': 0}

# %%
numerical_cols = df.select_dtypes(include=np.number).columns

for col in numerical_cols:
    # Check if the column is truly numeric and has enough data to plot
    if pd.api.types.is_numeric_dtype(df[col]) and df[col].dropna().size > 1:
        plt.figure(figsize=(6, 1))
        sns.boxplot(x=df[col].dropna(), color='skyblue') # Drop NaNs for plotting
        plt.title(f'Boxplot of {col}')
        plt.show()
    else:
        print(f"Skipping boxplot for non-numerical or empty column: {col}")
# Out:
# Skipping boxplot for non-numerical or empty column: Comments
